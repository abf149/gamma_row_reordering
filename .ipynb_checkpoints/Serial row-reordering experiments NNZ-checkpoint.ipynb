# %% [markdown]
# # Serial row-reordering experiments

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# Dimension/density grid search

metadata_row_range = [50, 100, 200, 500, 1000]
N_range = [2.0, 5.0, 10.0, 20.0, 30.0]

num_md_rows = len(metadata_row_range)
num_dens_vals = len(N_range)
metadata_row_range = np.array(metadata_row_range)
N_range = np.array(N_range)

result_metadata_row = np.zeros((num_dens_vals,num_md_rows))
result_N = np.zeros((num_dens_vals,num_md_rows))
result_time = np.zeros((num_dens_vals,num_md_rows))

# %%
for rdx in range(num_md_rows):
    for ddx in range(num_dens_vals):
        metadata_rows = metadata_row_range[rdx]
        N = N_range[ddx]
        
        result_metadata_row[ddx,rdx] = metadata_rows
        result_N[ddx,rdx] = N
        
        print("Row nonzeros:", N,"% Rows:",metadata_rows)
        cli = "./rcsr " + str(metadata_rows) + " " + str(metadata_rows) + " " + str(N/float(metadata_rows)) + "; ./sre < mat.csr > time.txt"
        os.system(cli)
        
        rt = 0
        with open('time.txt') as f:
            rt = f.readlines()
        
        result_time[ddx,rdx] = int(rt[0].strip())
# Out:
# Density: 0.1 % Rows: 50
# Density: 0.100000
# - Allocating CSR memory.
# - CSR preview (50 rows, 50 columns, 2 edges, density 0.100000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 0
# vertices[2] == 0
# vertices[3] == 0
# vertices[4] == 0
#
# ...
#
# vertices[46] == 1
# vertices[47] == 1
# vertices[48] == 2
# vertices[49] == 2
# vertices[50] == 2
# -- Edges and values:
# edges[0] == 20 values[0] == 1.000000
# edges[1] == 3 values[1] == 1.000000
#
# ...
#
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 2.0 % Rows: 50
# Density: 2.000000
# - Allocating CSR memory.
# - CSR preview (50 rows, 50 columns, 49 edges, density 2.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 1
# vertices[2] == 1
# vertices[3] == 2
# vertices[4] == 4
#
# ...
#
# vertices[46] == 41
# vertices[47] == 43
# vertices[48] == 44
# vertices[49] == 46
# vertices[50] == 49
# -- Edges and values:
# edges[0] == 31 values[0] == 1.000000
# edges[1] == 1 values[1] == 1.000000
# edges[2] == 17 values[2] == 1.000000
# edges[3] == 20 values[3] == 1.000000
# edges[4] == 15 values[4] == 1.000000
#
# ...
#
# edges[44] == 18 values[44] == 1.000000
# edges[45] == 30 values[45] == 1.000000
# edges[46] == 3 values[46] == 1.000000
# edges[47] == 12 values[47] == 1.000000
# edges[48] == 36 values[48] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 5.0 % Rows: 50
# Density: 5.000000
# - Allocating CSR memory.
# - CSR preview (50 rows, 50 columns, 122 edges, density 5.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 3
# vertices[2] == 4
# vertices[3] == 8
# vertices[4] == 11
#
# ...
#
# vertices[46] == 108
# vertices[47] == 111
# vertices[48] == 112
# vertices[49] == 116
# vertices[50] == 122
# -- Edges and values:
# edges[0] == 16 values[0] == 1.000000
# edges[1] == 31 values[1] == 1.000000
# edges[2] == 32 values[2] == 1.000000
# edges[3] == 30 values[3] == 1.000000
# edges[4] == 1 values[4] == 1.000000
#
# ...
#
# edges[117] == 8 values[117] == 1.000000
# edges[118] == 12 values[118] == 1.000000
# edges[119] == 36 values[119] == 1.000000
# edges[120] == 39 values[120] == 1.000000
# edges[121] == 45 values[121] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 10.0 % Rows: 50
# Density: 10.000000
# - Allocating CSR memory.
# - CSR preview (50 rows, 50 columns, 245 edges, density 10.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 7
# vertices[2] == 8
# vertices[3] == 14
# vertices[4] == 18
#
# ...
#
# vertices[46] == 221
# vertices[47] == 226
# vertices[48] == 229
# vertices[49] == 237
# vertices[50] == 245
# -- Edges and values:
# edges[0] == 1 values[0] == 1.000000
# edges[1] == 11 values[1] == 1.000000
# edges[2] == 16 values[2] == 1.000000
# edges[3] == 20 values[3] == 1.000000
# edges[4] == 31 values[4] == 1.000000
#
# ...
#
# edges[240] == 12 values[240] == 1.000000
# edges[241] == 36 values[241] == 1.000000
# edges[242] == 39 values[242] == 1.000000
# edges[243] == 42 values[243] == 1.000000
# edges[244] == 45 values[244] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 20.0 % Rows: 50
# Density: 20.000000
# - Allocating CSR memory.
# - CSR preview (50 rows, 50 columns, 525 edges, density 20.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 14
# vertices[2] == 21
# vertices[3] == 33
# vertices[4] == 45
#
# ...
#
# vertices[46] == 480
# vertices[47] == 491
# vertices[48] == 501
# vertices[49] == 515
# vertices[50] == 525
# -- Edges and values:
# edges[0] == 1 values[0] == 1.000000
# edges[1] == 4 values[1] == 1.000000
# edges[2] == 9 values[2] == 1.000000
# edges[3] == 11 values[3] == 1.000000
# edges[4] == 14 values[4] == 1.000000
#
# ...
#
# edges[520] == 27 values[520] == 1.000000
# edges[521] == 36 values[521] == 1.000000
# edges[522] == 39 values[522] == 1.000000
# edges[523] == 42 values[523] == 1.000000
# edges[524] == 45 values[524] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 30.0 % Rows: 50
# Density: 30.000000
# - Allocating CSR memory.
# - CSR preview (50 rows, 50 columns, 744 edges, density 30.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 19
# vertices[2] == 29
# vertices[3] == 43
# vertices[4] == 58
#
# ...
#
# vertices[46] == 686
# vertices[47] == 704
# vertices[48] == 715
# vertices[49] == 730
# vertices[50] == 744
# -- Edges and values:
# edges[0] == 1 values[0] == 1.000000
# edges[1] == 2 values[1] == 1.000000
# edges[2] == 4 values[2] == 1.000000
# edges[3] == 6 values[3] == 1.000000
# edges[4] == 9 values[4] == 1.000000
#
# ...
#
# edges[739] == 40 values[739] == 1.000000
# edges[740] == 42 values[740] == 1.000000
# edges[741] == 43 values[741] == 1.000000
# edges[742] == 45 values[742] == 1.000000
# edges[743] == 46 values[743] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 0.1 % Rows: 100
# Density: 0.100000
# - Allocating CSR memory.
# - CSR preview (100 rows, 100 columns, 13 edges, density 0.100000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 0
# vertices[2] == 0
# vertices[3] == 0
# vertices[4] == 0
#
# ...
#
# vertices[96] == 12
# vertices[97] == 12
# vertices[98] == 13
# vertices[99] == 13
# vertices[100] == 13
# -- Edges and values:
# edges[0] == 20 values[0] == 1.000000
# edges[1] == 53 values[1] == 1.000000
# edges[2] == 37 values[2] == 1.000000
# edges[3] == 80 values[3] == 1.000000
# edges[4] == 37 values[4] == 1.000000
#
# ...
#
# edges[8] == 48 values[8] == 1.000000
# edges[9] == 6 values[9] == 1.000000
# edges[10] == 64 values[10] == 1.000000
# edges[11] == 40 values[11] == 1.000000
# edges[12] == 88 values[12] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 2.0 % Rows: 100
# Density: 2.000000
# - Allocating CSR memory.
# - CSR preview (100 rows, 100 columns, 207 edges, density 2.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 1
# vertices[2] == 4
# vertices[3] == 5
# vertices[4] == 7
#
# ...
#
# vertices[96] == 196
# vertices[97] == 199
# vertices[98] == 203
# vertices[99] == 205
# vertices[100] == 207
# -- Edges and values:
# edges[0] == 31 values[0] == 1.000000
# edges[1] == 1 values[1] == 1.000000
# edges[2] == 67 values[2] == 1.000000
# edges[3] == 70 values[3] == 1.000000
# edges[4] == 65 values[4] == 1.000000
#
# ...
#
# edges[202] == 91 values[202] == 1.000000
# edges[203] == 37 values[203] == 1.000000
# edges[204] == 90 values[204] == 1.000000
# edges[205] == 7 values[205] == 1.000000
# edges[206] == 57 values[206] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 5.0 % Rows: 100
# Density: 5.000000
# - Allocating CSR memory.
# - CSR preview (100 rows, 100 columns, 507 edges, density 5.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 4
# vertices[2] == 11
# vertices[3] == 16
# vertices[4] == 20
#
# ...
#
# vertices[96] == 473
# vertices[97] == 481
# vertices[98] == 491
# vertices[99] == 499
# vertices[100] == 507
# -- Edges and values:
# edges[0] == 16 values[0] == 1.000000
# edges[1] == 31 values[1] == 1.000000
# edges[2] == 32 values[2] == 1.000000
# edges[3] == 80 values[3] == 1.000000
# edges[4] == 1 values[4] == 1.000000
#
# ...
#
# edges[502] == 57 values[502] == 1.000000
# edges[503] == 67 values[503] == 1.000000
# edges[504] == 76 values[504] == 1.000000
# edges[505] == 86 values[505] == 1.000000
# edges[506] == 95 values[506] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 10.0 % Rows: 100
# Density: 10.000000
# - Allocating CSR memory.
# - CSR preview (100 rows, 100 columns, 1010 edges, density 10.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 8
# vertices[2] == 18
# vertices[3] == 26
# vertices[4] == 36
#
# ...
#
# vertices[96] == 950
# vertices[97] == 963
# vertices[98] == 979
# vertices[99] == 993
# vertices[100] == 1010
# -- Edges and values:
# edges[0] == 1 values[0] == 1.000000
# edges[1] == 11 values[1] == 1.000000
# edges[2] == 16 values[2] == 1.000000
# edges[3] == 20 values[3] == 1.000000
# edges[4] == 31 values[4] == 1.000000
#
# ...
#
# edges[1005] == 70 values[1005] == 1.000000
# edges[1006] == 76 values[1006] == 1.000000
# edges[1007] == 86 values[1007] == 1.000000
# edges[1008] == 95 values[1008] == 1.000000
# edges[1009] == 98 values[1009] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 20.0 % Rows: 100
# Density: 20.000000
# - Allocating CSR memory.
# - CSR preview (100 rows, 100 columns, 2061 edges, density 20.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 21
# vertices[2] == 45
# vertices[3] == 63
# vertices[4] == 80
#
# ...
#
# vertices[96] == 1961
# vertices[97] == 1985
# vertices[98] == 2012
# vertices[99] == 2037
# vertices[100] == 2061
# -- Edges and values:
# edges[0] == 1 values[0] == 1.000000
# edges[1] == 4 values[1] == 1.000000
# edges[2] == 9 values[2] == 1.000000
# edges[3] == 11 values[3] == 1.000000
# edges[4] == 14 values[4] == 1.000000
#
# ...
#
# edges[2056] == 86 values[2056] == 1.000000
# edges[2057] == 88 values[2057] == 1.000000
# edges[2058] == 90 values[2058] == 1.000000
# edges[2059] == 95 values[2059] == 1.000000
# edges[2060] == 98 values[2060] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 30.0 % Rows: 100
# Density: 30.000000
# - Allocating CSR memory.
# - CSR preview (100 rows, 100 columns, 3001 edges, density 30.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 29
# vertices[2] == 58
# vertices[3] == 84
# vertices[4] == 110
#
# ...
#
# vertices[96] == 2859
# vertices[97] == 2894
# vertices[98] == 2926
# vertices[99] == 2963
# vertices[100] == 3001
# -- Edges and values:
# edges[0] == 1 values[0] == 1.000000
# edges[1] == 2 values[1] == 1.000000
# edges[2] == 4 values[2] == 1.000000
# edges[3] == 6 values[3] == 1.000000
# edges[4] == 9 values[4] == 1.000000
#
# ...
#
# edges[2996] == 88 values[2996] == 1.000000
# edges[2997] == 90 values[2997] == 1.000000
# edges[2998] == 91 values[2998] == 1.000000
# edges[2999] == 95 values[2999] == 1.000000
# edges[3000] == 98 values[3000] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 0.1 % Rows: 200
# Density: 0.100000
# - Allocating CSR memory.
# - CSR preview (200 rows, 200 columns, 38 edges, density 0.100000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 0
# vertices[2] == 0
# vertices[3] == 0
# vertices[4] == 0
#
# ...
#
# vertices[196] == 38
# vertices[197] == 38
# vertices[198] == 38
# vertices[199] == 38
# vertices[200] == 38
# -- Edges and values:
# edges[0] == 20 values[0] == 1.000000
# edges[1] == 153 values[1] == 1.000000
# edges[2] == 37 values[2] == 1.000000
# edges[3] == 80 values[3] == 1.000000
# edges[4] == 137 values[4] == 1.000000
#
# ...
#
# edges[33] == 173 values[33] == 1.000000
# edges[34] == 187 values[34] == 1.000000
# edges[35] == 163 values[35] == 1.000000
# edges[36] == 157 values[36] == 1.000000
# edges[37] == 175 values[37] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 2.0 % Rows: 200
# Density: 2.000000
# - Allocating CSR memory.
# - CSR preview (200 rows, 200 columns, 801 edges, density 2.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 4
# vertices[2] == 7
# vertices[3] == 9
# vertices[4] == 15
#
# ...
#
# vertices[196] == 785
# vertices[197] == 789
# vertices[198] == 794
# vertices[199] == 794
# vertices[200] == 801
# -- Edges and values:
# edges[0] == 31 values[0] == 1.000000
# edges[1] == 101 values[1] == 1.000000
# edges[2] == 167 values[2] == 1.000000
# edges[3] == 170 values[3] == 1.000000
# edges[4] == 65 values[4] == 1.000000
#
# ...
#
# edges[796] == 124 values[796] == 1.000000
# edges[797] == 126 values[797] == 1.000000
# edges[798] == 147 values[798] == 1.000000
# edges[799] == 153 values[799] == 1.000000
# edges[800] == 199 values[800] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 5.0 % Rows: 200
# Density: 5.000000
# - Allocating CSR memory.
# - CSR preview (200 rows, 200 columns, 1959 edges, density 5.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 11
# vertices[2] == 20
# vertices[3] == 26
# vertices[4] == 36
#
# ...
#
# vertices[196] == 1922
# vertices[197] == 1930
# vertices[198] == 1943
# vertices[199] == 1949
# vertices[200] == 1959
# -- Edges and values:
# edges[0] == 16 values[0] == 1.000000
# edges[1] == 31 values[1] == 1.000000
# edges[2] == 32 values[2] == 1.000000
# edges[3] == 80 values[3] == 1.000000
# edges[4] == 101 values[4] == 1.000000
#
# ...
#
# edges[1954] == 126 values[1954] == 1.000000
# edges[1955] == 147 values[1955] == 1.000000
# edges[1956] == 153 values[1956] == 1.000000
# edges[1957] == 198 values[1957] == 1.000000
# edges[1958] == 199 values[1958] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 10.0 % Rows: 200
# Density: 10.000000
# - Allocating CSR memory.
# - CSR preview (200 rows, 200 columns, 4007 edges, density 10.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 18
# vertices[2] == 36
# vertices[3] == 51
# vertices[4] == 72
#
# ...
#
# vertices[196] == 3940
# vertices[197] == 3955
# vertices[198] == 3973
# vertices[199] == 3988
# vertices[200] == 4007
# -- Edges and values:
# edges[0] == 1 values[0] == 1.000000
# edges[1] == 11 values[1] == 1.000000
# edges[2] == 16 values[2] == 1.000000
# edges[3] == 20 values[3] == 1.000000
# edges[4] == 31 values[4] == 1.000000
#
# ...
#
# edges[4002] == 147 values[4002] == 1.000000
# edges[4003] == 153 values[4003] == 1.000000
# edges[4004] == 172 values[4004] == 1.000000
# edges[4005] == 198 values[4005] == 1.000000
# edges[4006] == 199 values[4006] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 20.0 % Rows: 200
# Density: 20.000000
# - Allocating CSR memory.
# - CSR preview (200 rows, 200 columns, 8061 edges, density 20.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 45
# vertices[2] == 80
# vertices[3] == 124
# vertices[4] == 159
#
# ...
#
# vertices[196] == 7924
# vertices[197] == 7952
# vertices[198] == 7988
# vertices[199] == 8020
# vertices[200] == 8061
# -- Edges and values:
# edges[0] == 1 values[0] == 1.000000
# edges[1] == 4 values[1] == 1.000000
# edges[2] == 9 values[2] == 1.000000
# edges[3] == 11 values[3] == 1.000000
# edges[4] == 14 values[4] == 1.000000
#
# ...
#
# edges[8056] == 172 values[8056] == 1.000000
# edges[8057] == 192 values[8057] == 1.000000
# edges[8058] == 195 values[8058] == 1.000000
# edges[8059] == 198 values[8059] == 1.000000
# edges[8060] == 199 values[8060] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 30.0 % Rows: 200
# Density: 30.000000
# - Allocating CSR memory.
# - CSR preview (200 rows, 200 columns, 12009 edges, density 30.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 58
# vertices[2] == 110
# vertices[3] == 172
# vertices[4] == 230
#
# ...
#
# vertices[196] == 11786
# vertices[197] == 11838
# vertices[198] == 11896
# vertices[199] == 11952
# vertices[200] == 12009
# -- Edges and values:
# edges[0] == 1 values[0] == 1.000000
# edges[1] == 2 values[1] == 1.000000
# edges[2] == 4 values[2] == 1.000000
# edges[3] == 6 values[3] == 1.000000
# edges[4] == 9 values[4] == 1.000000
#
# ...
#
# edges[12004] == 192 values[12004] == 1.000000
# edges[12005] == 194 values[12005] == 1.000000
# edges[12006] == 195 values[12006] == 1.000000
# edges[12007] == 198 values[12007] == 1.000000
# edges[12008] == 199 values[12008] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 0.1 % Rows: 500
# Density: 0.100000
# - Allocating CSR memory.
# - CSR preview (500 rows, 500 columns, 260 edges, density 0.100000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 0
# vertices[2] == 0
# vertices[3] == 1
# vertices[4] == 3
#
# ...
#
# vertices[496] == 260
# vertices[497] == 260
# vertices[498] == 260
# vertices[499] == 260
# vertices[500] == 260
# -- Edges and values:
# edges[0] == 86 values[0] == 1.000000
# edges[1] == 51 values[1] == 1.000000
# edges[2] == 84 values[2] == 1.000000
# edges[3] == 462 values[3] == 1.000000
# edges[4] == 261 values[4] == 1.000000
#
# ...
#
# edges[255] == 357 values[255] == 1.000000
# edges[256] == 22 values[256] == 1.000000
# edges[257] == 30 values[257] == 1.000000
# edges[258] == 36 values[258] == 1.000000
# edges[259] == 181 values[259] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 2.0 % Rows: 500
# Density: 2.000000
# - Allocating CSR memory.
# - CSR preview (500 rows, 500 columns, 5061 edges, density 2.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 8
# vertices[2] == 14
# vertices[3] == 25
# vertices[4] == 33
#
# ...
#
# vertices[496] == 5015
# vertices[497] == 5033
# vertices[498] == 5044
# vertices[499] == 5053
# vertices[500] == 5061
# -- Edges and values:
# edges[0] == 115 values[0] == 1.000000
# edges[1] == 192 values[1] == 1.000000
# edges[2] == 205 values[2] == 1.000000
# edges[3] == 301 values[3] == 1.000000
# edges[4] == 342 values[4] == 1.000000
#
# ...
#
# edges[5056] == 257 values[5056] == 1.000000
# edges[5057] == 286 values[5057] == 1.000000
# edges[5058] == 368 values[5058] == 1.000000
# edges[5059] == 377 values[5059] == 1.000000
# edges[5060] == 499 values[5060] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 5.0 % Rows: 500
# Density: 5.000000
# - Allocating CSR memory.
# - CSR preview (500 rows, 500 columns, 12533 edges, density 5.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 17
# vertices[2] == 43
# vertices[3] == 67
# vertices[4] == 96
#
# ...
#
# vertices[496] == 12438
# vertices[497] == 12469
# vertices[498] == 12490
# vertices[499] == 12511
# vertices[500] == 12533
# -- Edges and values:
# edges[0] == 53 values[0] == 1.000000
# edges[1] == 57 values[1] == 1.000000
# edges[2] == 115 values[2] == 1.000000
# edges[3] == 122 values[3] == 1.000000
# edges[4] == 128 values[4] == 1.000000
#
# ...
#
# edges[12528] == 407 values[12528] == 1.000000
# edges[12529] == 427 values[12529] == 1.000000
# edges[12530] == 450 values[12530] == 1.000000
# edges[12531] == 495 values[12531] == 1.000000
# edges[12532] == 499 values[12532] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 10.0 % Rows: 500
# Density: 10.000000
# - Allocating CSR memory.
# - CSR preview (500 rows, 500 columns, 25145 edges, density 10.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 40
# vertices[2] == 91
# vertices[3] == 147
# vertices[4] == 197
#
# ...
#
# vertices[496] == 24961
# vertices[497] == 25016
# vertices[498] == 25063
# vertices[499] == 25101
# vertices[500] == 25145
# -- Edges and values:
# edges[0] == 6 values[0] == 1.000000
# edges[1] == 14 values[1] == 1.000000
# edges[2] == 38 values[2] == 1.000000
# edges[3] == 53 values[3] == 1.000000
# edges[4] == 57 values[4] == 1.000000
#
# ...
#
# edges[25140] == 450 values[25140] == 1.000000
# edges[25141] == 459 values[25141] == 1.000000
# edges[25142] == 469 values[25142] == 1.000000
# edges[25143] == 495 values[25143] == 1.000000
# edges[25144] == 499 values[25144] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 20.0 % Rows: 500
# Density: 20.000000
# - Allocating CSR memory.
# - CSR preview (500 rows, 500 columns, 49992 edges, density 20.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 115
# vertices[2] == 237
# vertices[3] == 344
# vertices[4] == 432
#
# ...
#
# vertices[496] == 49631
# vertices[497] == 49715
# vertices[498] == 49812
# vertices[499] == 49896
# vertices[500] == 49992
# -- Edges and values:
# edges[0] == 2 values[0] == 1.000000
# edges[1] == 13 values[1] == 1.000000
# edges[2] == 16 values[2] == 1.000000
# edges[3] == 17 values[3] == 1.000000
# edges[4] == 25 values[4] == 1.000000
#
# ...
#
# edges[49987] == 463 values[49987] == 1.000000
# edges[49988] == 468 values[49988] == 1.000000
# edges[49989] == 479 values[49989] == 1.000000
# edges[49990] == 483 values[49990] == 1.000000
# edges[49991] == 497 values[49991] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 30.0 % Rows: 500
# Density: 30.000000
# - Allocating CSR memory.
# - CSR preview (500 rows, 500 columns, 75422 edges, density 30.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 147
# vertices[2] == 285
# vertices[3] == 448
# vertices[4] == 592
#
# ...
#
# vertices[496] == 74836
# vertices[497] == 74975
# vertices[498] == 75129
# vertices[499] == 75267
# vertices[500] == 75422
# -- Edges and values:
# edges[0] == 3 values[0] == 1.000000
# edges[1] == 4 values[1] == 1.000000
# edges[2] == 5 values[2] == 1.000000
# edges[3] == 7 values[3] == 1.000000
# edges[4] == 15 values[4] == 1.000000
#
# ...
#
# edges[75417] == 485 values[75417] == 1.000000
# edges[75418] == 490 values[75418] == 1.000000
# edges[75419] == 491 values[75419] == 1.000000
# edges[75420] == 493 values[75420] == 1.000000
# edges[75421] == 498 values[75421] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 0.1 % Rows: 1000
# Density: 0.100000
# - Allocating CSR memory.
# - CSR preview (1000 rows, 1000 columns, 1003 edges, density 0.100000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 1
# vertices[2] == 2
# vertices[3] == 3
# vertices[4] == 3
#
# ...
#
# vertices[996] == 1000
# vertices[997] == 1000
# vertices[998] == 1001
# vertices[999] == 1002
# vertices[1000] == 1003
# -- Edges and values:
# edges[0] == 523 values[0] == 1.000000
# edges[1] == 164 values[1] == 1.000000
# edges[2] == 724 values[2] == 1.000000
# edges[3] == 241 values[3] == 1.000000
# edges[4] == 413 values[4] == 1.000000
#
# ...
#
# edges[998] == 469 values[998] == 1.000000
# edges[999] == 831 values[999] == 1.000000
# edges[1000] == 675 values[1000] == 1.000000
# edges[1001] == 791 values[1001] == 1.000000
# edges[1002] == 744 values[1002] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 2.0 % Rows: 1000
# Density: 2.000000
# - Allocating CSR memory.
# - CSR preview (1000 rows, 1000 columns, 19983 edges, density 2.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 22
# vertices[2] == 43
# vertices[3] == 68
# vertices[4] == 85
#
# ...
#
# vertices[996] == 19908
# vertices[997] == 19919
# vertices[998] == 19937
# vertices[999] == 19962
# vertices[1000] == 19983
# -- Edges and values:
# edges[0] == 40 values[0] == 1.000000
# edges[1] == 78 values[1] == 1.000000
# edges[2] == 122 values[2] == 1.000000
# edges[3] == 123 values[3] == 1.000000
# edges[4] == 160 values[4] == 1.000000
#
# ...
#
# edges[19978] == 795 values[19978] == 1.000000
# edges[19979] == 824 values[19979] == 1.000000
# edges[19980] == 921 values[19980] == 1.000000
# edges[19981] == 942 values[19981] == 1.000000
# edges[19982] == 978 values[19982] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 5.0 % Rows: 1000
# Density: 5.000000
# - Allocating CSR memory.
# - CSR preview (1000 rows, 1000 columns, 49723 edges, density 5.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 48
# vertices[2] == 108
# vertices[3] == 158
# vertices[4] == 209
#
# ...
#
# vertices[996] == 49520
# vertices[997] == 49567
# vertices[998] == 49619
# vertices[999] == 49667
# vertices[1000] == 49723
# -- Edges and values:
# edges[0] == 4 values[0] == 1.000000
# edges[1] == 58 values[1] == 1.000000
# edges[2] == 63 values[2] == 1.000000
# edges[3] == 71 values[3] == 1.000000
# edges[4] == 87 values[4] == 1.000000
#
# ...
#
# edges[49718] == 927 values[49718] == 1.000000
# edges[49719] == 928 values[49719] == 1.000000
# edges[49720] == 971 values[49720] == 1.000000
# edges[49721] == 978 values[49721] == 1.000000
# edges[49722] == 996 values[49722] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 10.0 % Rows: 1000
# Density: 10.000000
# - Allocating CSR memory.
# - CSR preview (1000 rows, 1000 columns, 100329 edges, density 10.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 112
# vertices[2] == 209
# vertices[3] == 297
# vertices[4] == 384
#
# ...
#
# vertices[996] == 99957
# vertices[997] == 100047
# vertices[998] == 100150
# vertices[999] == 100241
# vertices[1000] == 100329
# -- Edges and values:
# edges[0] == 13 values[0] == 1.000000
# edges[1] == 22 values[1] == 1.000000
# edges[2] == 29 values[2] == 1.000000
# edges[3] == 34 values[3] == 1.000000
# edges[4] == 35 values[4] == 1.000000
#
# ...
#
# edges[100324] == 949 values[100324] == 1.000000
# edges[100325] == 975 values[100325] == 1.000000
# edges[100326] == 987 values[100326] == 1.000000
# edges[100327] == 992 values[100327] == 1.000000
# edges[100328] == 993 values[100328] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 20.0 % Rows: 1000
# Density: 20.000000
# - Allocating CSR memory.
# - CSR preview (1000 rows, 1000 columns, 199599 edges, density 20.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 209
# vertices[2] == 398
# vertices[3] == 588
# vertices[4] == 809
#
# ...
#
# vertices[996] == 198831
# vertices[997] == 199023
# vertices[998] == 199217
# vertices[999] == 199401
# vertices[1000] == 199599
# -- Edges and values:
# edges[0] == 3 values[0] == 1.000000
# edges[1] == 7 values[1] == 1.000000
# edges[2] == 8 values[2] == 1.000000
# edges[3] == 10 values[3] == 1.000000
# edges[4] == 19 values[4] == 1.000000
#
# ...
#
# edges[199594] == 991 values[199594] == 1.000000
# edges[199595] == 992 values[199595] == 1.000000
# edges[199596] == 993 values[199596] == 1.000000
# edges[199597] == 994 values[199597] == 1.000000
# edges[199598] == 999 values[199598] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# Density: 30.0 % Rows: 1000
# Density: 30.000000
# - Allocating CSR memory.
# - CSR preview (1000 rows, 1000 columns, 300574 edges, density 30.000000%):
# -- Vertices:
# vertices[0] == 0
# vertices[1] == 289
# vertices[2] == 578
# vertices[3] == 879
# vertices[4] == 1169
#
# ...
#
# vertices[996] == 299373
# vertices[997] == 299682
# vertices[998] == 299982
# vertices[999] == 300297
# vertices[1000] == 300574
# -- Edges and values:
# edges[0] == 1 values[0] == 1.000000
# edges[1] == 2 values[1] == 1.000000
# edges[2] == 4 values[2] == 1.000000
# edges[3] == 5 values[3] == 1.000000
# edges[4] == 7 values[4] == 1.000000
#
# ...
#
# edges[300569] == 985 values[300569] == 1.000000
# edges[300570] == 989 values[300570] == 1.000000
# edges[300571] == 990 values[300571] == 1.000000
# edges[300572] == 991 values[300572] == 1.000000
# edges[300573] == 997 values[300573] == 1.000000
# Saving CSR representation to file.
# - Writing metadata line.
# - Writing vertices.
# - Writing edges.
# - Writing values.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2366/2293432129.py in <module>
#      15             rt = f.readlines()
#      16
# ---> 17         result_time[ddx,rdx] = int(rt[0].strip())
#
# IndexError: list index out of range

# %%
import pickle

data = {"metadata_row_range":metadata_row_range, "N_range":N_range, \
        "num_md_rows":num_md_rows, "num_dens_vals":num_dens_vals, \
        "result_metadata_row":result_metadata_row, "result_N":result_N, \
        "result_time":result_time}

# open a file, where you ant to store the data
file = open('serial_experiments_data', 'wb')

# dump information to that file
pickle.dump(data, file)

# close the file
file.close()

# %%
plt.figure(figsize=(12, 25), dpi=160)
plt.subplot(311)
for ddx in range(num_dens_vals):
    plt.plot(result_metadata_row[ddx,:],result_time[ddx,:],'--o')
plt.grid(True)
plt.xlabel('Rows')
plt.ylabel('Run-time (ms)')
plt.title('Serial row-reordering: run-time scaling with square matrix dimension (vertex count)')
plt.legend(["row-NNZ="+str(n)+"%" for n in N_range])

    
plt.subplot(312)
for rdx in range(num_md_rows):
    plt.plot(result_N[:,rdx]/float(metadata_rows),result_time[:,rdx],'--o')
plt.grid(True)
plt.xlabel('Density')
plt.ylabel('Run-time (ms)')
plt.title('Serial row-reordering: run-time scaling with square matrix density')
plt.legend(["Rows="+str(r) for r in metadata_row_range])

plt.subplot(313)
for rdx in range(num_md_rows):
    plt.plot(result_N[:,rdx],result_time[:,rdx],'--o')
plt.grid(True)
plt.xlabel('row-NNZ')
plt.ylabel('Run-time (ms)')
plt.title('Serial row-reordering: run-time scaling with average nonzeros in row (row-NNZ, density*row_dimension)')
plt.legend(["Rows="+str(r) for r in metadata_row_range])
